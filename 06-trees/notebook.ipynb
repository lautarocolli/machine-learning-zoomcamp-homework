# %% [markdown]
# ## 6.1 Credit Risk Scoring

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 6.2 Data cleaning and preparation

# %%
df = pd.read_csv('CreditScoring.csv')

# %%
df.head()
# Out:
#    Status  Seniority  Home  Time  Age  Marital  Records  Job  Expenses  \
# 0       1          9     1    60   30        2        1    3        73
# 1       1         17     1    60   58        3        1    1        48
# 2       2         10     2    36   46        2        2    3        90
# 3       1          0     1    60   24        1        1    1        63
# 4       1          0     1    36   26        1        1    1        46
#
#    Income  Assets  Debt  Amount  Price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.columns = df.columns.str.lower()

# %%
status_values = {
    1: 'ok',
    2: 'default',
    0: 'unk'
}
df.status = df.status.map(status_values)

# %%
home_values = {
    1: 'rent',
    2: 'owner',
    3: 'private',
    4: 'ignore',
    5: 'parents',
    6: 'other',
    0: 'unk'
}

df.home = df.home.map(home_values)

marital_values = {
    1: 'single',
    2: 'married',
    3: 'widow',
    4: 'separated',
    5: 'divorced',
    0: 'unk'
}

df.marital = df.marital.map(marital_values)

records_values = {
    1: 'no',
    2: 'yes',
    0: 'unk'
}

df.records = df.records.map(records_values)

job_values = {
    1: 'fixed',
    2: 'partime',
    3: 'freelance',
    4: 'others',
    0: 'unk'
}

df.job = df.job.map(job_values)

# %%
df.head()
# Out:
#     status  seniority   home  time  age  marital records        job  expenses  \
# 0       ok          9   rent    60   30  married      no  freelance        73
# 1       ok         17   rent    60   58    widow      no      fixed        48
# 2  default         10  owner    36   46  married     yes  freelance        90
# 3       ok          0   rent    60   24   single      no      fixed        63
# 4       ok          0   rent    36   26   single      no      fixed        46
#
#    income  assets  debt  amount  price
# 0     129       0     0     800    846
# 1     131       0     0    1000   1658
# 2     200    3000     0    2000   2985
# 3     182    2500     0     900   1325
# 4     107       0     0     310    910

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses      income      assets  \
# count     4455.0  4455.0  4455.0    4455.0      4455.0      4455.0
# mean         8.0    46.0    37.0      56.0    763317.0   1060341.0
# std          8.0    15.0    11.0      20.0   8703625.0  10217569.0
# min          0.0     6.0    18.0      35.0         0.0         0.0
# 25%          2.0    36.0    28.0      35.0        80.0         0.0
# 50%          5.0    48.0    36.0      51.0       120.0      3500.0
# 75%         12.0    60.0    45.0      72.0       166.0      6000.0
# max         48.0    72.0    68.0     180.0  99999999.0  99999999.0
#
#              debt  amount    price
# count      4455.0  4455.0   4455.0
# mean     404382.0  1039.0   1463.0
# std     6344253.0   475.0    628.0
# min           0.0   100.0    105.0
# 25%           0.0   700.0   1118.0
# 50%           0.0  1000.0   1400.0
# 75%           0.0  1300.0   1692.0
# max    99999999.0  5000.0  11140.0

# %%
for c in ['income', 'assets', 'debt']:
    df[c] = df[c].replace(to_replace=99999999, value=np.nan)

# %%
df.describe().round()
# Out:
#        seniority    time     age  expenses  income    assets     debt  amount  \
# count     4455.0  4455.0  4455.0    4455.0  4421.0    4408.0   4437.0  4455.0
# mean         8.0    46.0    37.0      56.0   131.0    5403.0    343.0  1039.0
# std          8.0    15.0    11.0      20.0    86.0   11573.0   1246.0   475.0
# min          0.0     6.0    18.0      35.0     0.0       0.0      0.0   100.0
# 25%          2.0    36.0    28.0      35.0    80.0       0.0      0.0   700.0
# 50%          5.0    48.0    36.0      51.0   120.0    3000.0      0.0  1000.0
# 75%         12.0    60.0    45.0      72.0   165.0    6000.0      0.0  1300.0
# max         48.0    72.0    68.0     180.0   959.0  300000.0  30000.0  5000.0
#
#          price
# count   4455.0
# mean    1463.0
# std      628.0
# min      105.0
# 25%     1118.0
# 50%     1400.0
# 75%     1692.0
# max    11140.0

# %%
df.status.value_counts()
# Out:
# status
# ok         3200
# default    1254
# unk           1
# Name: count, dtype: int64

# %%
df = df[df.status != 'unk'].reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_full_train = df_full_train.reset_index(drop=True)

# %%
y_train = df_train.status.map(lambda x: 1 if x == 'default' else 0).values
y_val = df_val.status.map(lambda x: 1 if x == 'default' else 0).values
y_test = df_test.status.map(lambda x: 1 if x == 'default' else 0).values
df_full_train.status.map(lambda x: 1 if x == 'default' else 0).values
# Out:
# array([0, 1, 0, ..., 0, 0, 1], shape=(3563,))

# %%
del df_train['status']
del df_val['status']
del df_test['status']
del df_full_train['status']

# %% [markdown]
# ## 6.3 Decision trees

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score

# %%
pipeline = make_pipeline(
    DictVectorizer(sparse=False),
    DecisionTreeClassifier()
)

# %%
train_dicts = df_train.fillna(0).to_dict(orient='records')

# %%
pipeline.fit(train_dicts, y_train)
# Out:
# Pipeline(steps=[('dictvectorizer', DictVectorizer(sparse=False)),
#                 ('decisiontreeclassifier', DecisionTreeClassifier())])

# %%
val_dicts = df_val.fillna(0).to_dict(orient='records')

# %%
y_pred = pipeline.predict_proba(val_dicts)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.6524515027487829

# %%
y_pred = pipeline.predict_proba(train_dicts)[:, 1]
roc_auc_score(y_train, y_pred)
# Out:
# 1.0

# %% [markdown]
# validation y_pred roc_auc_score = 0.65
#
# training y_pred roc_auc_score = 1.0
#
# Clear overfitting.

# %%
pipeline = make_pipeline(
    DictVectorizer(sparse=False),
    DecisionTreeClassifier(max_depth=3)
)

# %%
pipeline.fit(train_dicts, y_train)
y_pred_val = pipeline.predict_proba(val_dicts)[:, 1]
roc_auc_score_val = roc_auc_score(y_val, y_pred_val)
y_pred_train = pipeline.predict_proba(train_dicts)[:, 1]
roc_auc_score_train = roc_auc_score(y_train, y_pred_train)

# %%
print('roc_auc_score_train:', roc_auc_score_train)
print('roc_auc_score_val:', roc_auc_score_val)
# Out:
# roc_auc_score_train: 0.7761016984958594
# roc_auc_score_val: 0.7389079944782155

# %%
from sklearn.tree import export_text

# %%
dt = pipeline.named_steps['decisiontreeclassifier']

# %%
print(export_text(dt, feature_names=pipeline.named_steps['dictvectorizer'].get_feature_names_out()))
# Out:
# |--- records=yes <= 0.50
# |   |--- job=partime <= 0.50
# |   |   |--- income <= 74.50
# |   |   |   |--- class: 0
# |   |   |--- income >  74.50
# |   |   |   |--- class: 0
# |   |--- job=partime >  0.50
# |   |   |--- assets <= 8750.00
# |   |   |   |--- class: 1
# |   |   |--- assets >  8750.00
# |   |   |   |--- class: 0
# |--- records=yes >  0.50
# |   |--- seniority <= 6.50
# |   |   |--- amount <= 862.50
# |   |   |   |--- class: 0
# |   |   |--- amount >  862.50
# |   |   |   |--- class: 1
# |   |--- seniority >  6.50
# |   |   |--- income <= 103.50
# |   |   |   |--- class: 1
# |   |   |--- income >  103.50
# |   |   |   |--- class: 0

# %% [markdown]
# ## 6.4 Decision Tree Learning Algorithm

# %% [markdown]
# Learned about how the Algorithm for Decision Trees decides the branches

# %% [markdown]
# ## 6.5 Decision trees parameter tuning

# %%
X_train = pipeline.named_steps['dictvectorizer'].transform(train_dicts)
X_val = pipeline.named_steps['dictvectorizer'].transform(val_dicts)

# %%
for d in [1, 2, 3, 4, 5, 6, 10, 15, 20, None]:
    dt = DecisionTreeClassifier(max_depth=d)
    dt.fit(X_train, y_train)

    y_pred_val = dt.predict_proba(X_val)[:, 1]
    roc_auc_score_val = roc_auc_score(y_val, y_pred_val)

    print(f'max_depth={d} => roc_auc_score_val: {roc_auc_score_val:.3f}')
# Out:
# max_depth=1 => roc_auc_score_val: 0.606
# max_depth=2 => roc_auc_score_val: 0.669
# max_depth=3 => roc_auc_score_val: 0.739
# max_depth=4 => roc_auc_score_val: 0.761
# max_depth=5 => roc_auc_score_val: 0.766
# max_depth=6 => roc_auc_score_val: 0.750
# max_depth=10 => roc_auc_score_val: 0.678
# max_depth=15 => roc_auc_score_val: 0.647
# max_depth=20 => roc_auc_score_val: 0.668
# max_depth=None => roc_auc_score_val: 0.654

# %%
scores = []
for d in [1, 2, 3, 4, 5, 6, 10, 15, 20, None]:
    for s in [1, 2, 5, 10, 15, 20, 100, 200, 500]:
        dt = DecisionTreeClassifier(max_depth=d, min_samples_leaf=s)
        dt.fit(X_train, y_train)

        y_pred_val = dt.predict_proba(X_val)[:, 1]
        roc_auc_score_val = roc_auc_score(y_val, y_pred_val)
        scores.append((d, s, roc_auc_score_val))
df_scores = pd.DataFrame(scores, columns=['max_depth', 'min_samples_leaf', 'roc_auc_score_val'])
df_scores.sort_values(by='roc_auc_score_val', ascending=False)
# Out:
#     max_depth  min_samples_leaf  roc_auc_score_val
# 58       10.0                15           0.789812
# 67       15.0                15           0.788640
# 76       20.0                15           0.787084
# 85        NaN                15           0.786591
# 49        6.0                15           0.785319
# ..        ...               ...                ...
# 3         1.0                10           0.605864
# 5         1.0                20           0.605864
# 4         1.0                15           0.605864
# 7         1.0               200           0.605864
# 6         1.0               100           0.605864
#
# [90 rows x 3 columns]

# %%
df_scores_pivot = df_scores.pivot(index='min_samples_leaf', columns='max_depth', values='roc_auc_score_val')

# %%
heatmap = sns.heatmap(df_scores_pivot, annot=True, fmt=".3f")
plt.title('ROC AUC Score on Validation Set')
plt.xlabel('max_depth')
plt.ylabel('min_samples_leaf')
plt.show()

# %%
pipeline = make_pipeline(
    DictVectorizer(sparse=False),
    DecisionTreeClassifier(max_depth=6, min_samples_leaf=15)
)

# %%
pipeline.fit(train_dicts, y_train)
# Out:
# Pipeline(steps=[('dictvectorizer', DictVectorizer(sparse=False)),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=6, min_samples_leaf=15))])

# %% [markdown]
# ## 6.6 Ensembles and random forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=10, random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=1)

# %%
y_pred_rf = rf.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred_rf)
# Out:
# 0.7744726453706618

# %%
scores = []
for n in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=n, random_state=1)
    rf.fit(X_train, y_train)
    y_pred_rf = rf.predict_proba(X_val)[:, 1]
    auc = roc_auc_score(y_val, y_pred_rf)
    scores.append((n, auc))
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'roc_auc_score_val'])
df_scores.plot(x='n_estimators', y='roc_auc_score_val', marker='o')
plt.title
# Out:
# <function matplotlib.pyplot.title(label: 'str', fontdict: 'dict[str, Any] | None' = None, loc: "Literal['left', 'center', 'right'] | None" = None, pad: 'float | None' = None, *, y: 'float | None' = None, **kwargs) -> 'Text'>

# %%
scores = []

for d in [5, 10, 15]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=d, random_state=1)
        rf.fit(X_train, y_train)
        y_pred_rf = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred_rf)
        scores.append((d, n, auc))
df_scores = pd.DataFrame(scores, columns=['max_depth', 'n_estimators', 'roc_auc_score_val'])

# %%
for d in [5, 10, 15]:
    df_subset = df_scores[df_scores['max_depth'] == d]
    plt.plot(df_subset['n_estimators'], df_subset['roc_auc_score_val'], marker='o', label=f'max_depth={d}')
plt.title('ROC AUC Score on Validation Set vs Number of Estimators')
plt.xlabel('n_estimators')
plt.ylabel('roc_auc_score_val')
plt.legend()

# %%
max_depth=10

# %%
scores = []

for s in [1, 3, 5, 10, 50]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n, max_depth=10, min_samples_leaf=s, random_state=1)
        rf.fit(X_train, y_train)
        y_pred_rf = rf.predict_proba(X_val)[:, 1]
        auc = roc_auc_score(y_val, y_pred_rf)
        scores.append((s, n, auc))
df_scores = pd.DataFrame(scores, columns=['min_samples_leaf', 'n_estimators', 'roc_auc_score_val'])

# %%
for s in [1, 3, 5, 10, 50]:
    df_subset = df_scores[df_scores['min_samples_leaf'] == s]
    plt.plot(df_subset['n_estimators'], df_subset['roc_auc_score_val'], marker='o', label=f'min_samples_leaf={s}')
plt.title('ROC AUC Score on Validation Set vs min_samples_leaf')
plt.xlabel('n_estimators')
plt.ylabel('roc_auc_score_val')
plt.legend()

# %%
min_samples_leaf=3

# %%
rf = RandomForestClassifier(n_estimators=100, 
                            max_depth=max_depth,
                            min_samples_leaf=min_samples_leaf,
                            random_state=1)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=1)

# %% [markdown]
# ## 6.7 Gradient boosting and XGBoost

# %%
import xgboost as xgb

# %%
dv =DictVectorizer(sparse=False)
dv.fit(train_dicts)
features = dv.get_feature_names_out().tolist()

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1
}
model = xgb.train(xgb_params, dtrain, num_boost_round=10)

# %%
y_pred = model.predict(dval)

# %%
roc_auc_score(y_val, y_pred)
# Out:
# 0.8118506454190986

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
# %%capture output
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'binary:logistic',
    'eval_metric': 'auc',
    'nthread': 8,

    'seed': 1,
    'verbosity': 1
}
model = xgb.train(xgb_params, dtrain, evals=watchlist,
                  verbose_eval=5, num_boost_round=200)

# %%
def parse_xgb_output(output):
    results = []

    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line = line.split('\t')

        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])

        results.append((it, train, val))
    
    columns = ['num_iter', 'train_auc', 'val_auc']
    df_results = pd.DataFrame(results, columns=columns)
    return df_results

# %%
df_score = parse_xgb_output(output)

# %%
plt.plot(df_score.num_iter, df_score.train_auc, label='train')
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()

# %%
plt.plot(df_score.num_iter, df_score.val_auc, label='val')
plt.legend()

# %% [markdown]
# ## 6.8 XGBoost Parameter Tuning

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.3, 
    'max_depth': 6,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
key = 'eta=%s' % (xgb_params['eta'])
scores[key] = parse_xgb_output(output)
# Out:
# 'eta=0.3'

# %%
scores.keys()
# Out:
# dict_keys(['eta=0.01', 'eta=0.1', 'eta=0.5', 'eta=1', 'eta=0.3'])

# %%
for eta in [0.01, 0.1, 0.3, 0.5, 1]:
    df_score = scores['eta=%s' % eta]
    plt.plot(df_score.num_iter, df_score.val_auc, label=eta)
    plt.title('Validation AUC vs Number of Iterations')
    plt.xlabel('num_iter')
    plt.ylabel('val_auc')
plt.legend()

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 15,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
key = 'max_depth=%s' % (xgb_params['max_depth'])
scores[key] = parse_xgb_output(output)

# %%
scores.keys()
# Out:
# dict_keys(['max_depth=6', 'max_depth=4', 'max_depth=3', 'max_depth=10', 'max_depth=15'])

# %%
for max_depth in ['max_depth=6', 'max_depth=4', 'max_depth=3']:
    df_score = scores[max_depth]
    plt.plot(df_score.num_iter, df_score.val_auc, label=max_depth)
    plt.title('Validation AUC vs Number of Iterations')
    plt.xlabel('num_iter')
    plt.ylabel('val_auc')
plt.ylim(0.8,.84)
plt.legend()

# %%
scores = {}

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 30,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=200,
                  verbose_eval=5,
                  evals=watchlist)

# %%
key = 'min_child_weight=%s' % (xgb_params['min_child_weight'])
scores[key] = parse_xgb_output(output)

# %%
scores.keys()
# Out:
# dict_keys(['min_child_weight=1', 'min_child_weight=10', 'min_child_weight=30'])

# %%
for min_child_weight in ['min_child_weight=1', 'min_child_weight=10', 'min_child_weight=30']:
    df_score = scores[min_child_weight]
    plt.plot(df_score.num_iter, df_score.val_auc, label=min_child_weight)
    plt.title('Validation AUC vs Number of Iterations')
    plt.xlabel('num_iter')
    plt.ylabel('val_auc')
plt.ylim(0.82,.84)
plt.legend()

# %%
# %%capture output

xgb_params = {
    'eta': 0.1, 
    'max_depth': 3,
    'min_child_weight': 1,
    
    'objective': 'binary:logistic',
    'eval_metric': 'auc',

    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(xgb_params, dtrain, num_boost_round=175,
                  verbose_eval=5,
                  evals=watchlist)

# %% [markdown]
# ## 6.9 Selecting the best model
